# %% [markdown]
# # Viewing the universe in different colors and wavelengths
# ---
# <div>Michael C. Stroh</br>
# michael.stroh@northwestern.edu</br>
# Center for Interdisciplinary Exploration and Research in Astrophysics</br>
# Northwestern University</br>
# 2022
# </div>
#
# ---

# %% [markdown]
# ## Section 1: Background

# %% [markdown]
# ### Section 1.1: The Electromagnetic Spectrum

# %% [markdown]
# Since the Sun shines in the the optical portion of the electromagnetic spectrum, we have evolved to observe optical light.
# Radio, infrared, ultraviolet, X-rays and gamma rays are also important types of light, that we can also use to study the universe.
# In this project, you will create images from different parts of the electromagnetic spectrum.

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/9/99/EM_Spectrum3-new.jpg)

# %% [markdown]
# Above is a cartoon from NASA that shows different ways to characterize the electromagnetic spectrum.
#
# * Hotter things are 'bluer,' while colder things are 'redder.'
# * Temperature is related to the frequency. Frequency is often specified in units of Hz (hertz) and 1 Hz is equal to units of s$^{-1}$. In the case of light, the frequency specifies how often the light peaks in one second if using units of Hz.

# %% [markdown]
# We have two key equations to convert between energy, frequency and wavelength:
# 1. $E=hf$, and
# 2. $c = f\lambda$.
#
# * $E$ is the energy (units of Joules which is equal to $\textrm{kg}\,\textrm{m}^2\,\textrm{s}^{-2}$ in SI).
# * $h$ is Plank's constant ($6.626\times10^{-34}\,\textrm{m}^2\,\textrm{kg}\,\textrm{s}^{-1}$ in SI).
# * $f$ is the frequency (units of Hz or s$^{-1}$ in SI).
# * $c$ is the speed of light ($2.9979\times10^{8}\,\textrm{m/s}$ in SI)
# * $\lambda$ is the wavelength (units of meters in SI).

# %% [markdown]
# Combining these two equations and the image above, you should be able to think of these properties as:
#
# * Redder things emit longer wavelength light, but lower frequencies.
# * Bluer things emit smaller wavelength light, but higher frequencies.
#
# Astronomers often need to convert between energy, frequency and wavelength. Some astronomers also are more comfortable viewing astronomy in terms of one of these quantities and convert as necessary.

# %% [markdown]
# ### Section 1.2: Different types of telescopes

# %% [markdown]
# In this project, you will use images from the following telescopes.

# %% [markdown]
# #### Pan-STARRS
# ![](https://outerspace.stsci.edu/download/attachments/10257385/PanSTARRS1_dome_small.jpg?version=2&modificationDate=1482088820000&api=v2)
#
# The Panoramic Survey Telescope and Rapid Response System (referred to as Pan-STARRS) is located in Hawaii and observes the sky in optical and infrared filters. More information can be found at [https://panstarrs.stsci.edu/](https://panstarrs.stsci.edu/).

# %% [markdown]
# #### The VLA
# ![](https://science.nrao.edu/facilities/vla/images/vla_panorama_lo.jpg/image_large)
#
# The Karl G. Jansky Very Large Array (referred to as the VLA) consists of 27 large radio telescopes in New Mexico. The VLA combines the signal from all of the dishes to act as a much larger telescope. More information on the VLA can be found at [https://public.nrao.edu/telescopes/vla/](https://public.nrao.edu/telescopes/vla/).

# %% [markdown]
# ####Chandra
# ![](https://svs.gsfc.nasa.gov/vis/a010000/a011100/a011185/Image4_1024x576.jpg)
#
# The Chandra X-ray Observatory is NASA's premier X-ray observatory and orbits the Earth in a 64 hour orbit.

# %% [markdown]
# ### Section 1.3: The Crab Nebula

# %% [markdown]
# In this project, you will be using images of the Crab Nebula.
# The Crab Nebula was created by a supernova that happened in 1054 AD, and was was observed by Chinese astronomers.
# at the center of the supernova remnant lies a pulsar (a spinning neutron star). This pulsar, the Crab pulsar, is the collapsed remains of the star.
#
# More information about the Crab Nebula can be found at the following links:
# * [NASA page on the Crab Nebula](https://www.nasa.gov/feature/goddard/2017/messier-1-the-crab-nebula)
# * [Wikipedia Crab Nebula page](https://en.wikipedia.org/wiki/Crab_Nebula)

# %% [markdown]
# ## Section 2: Optical images - a wavelength view of the electromagnetic spectrum

# %% [markdown]
# ![](https://outerspace.stsci.edu/download/attachments/10257347/tonryphotometricsystem.jpg?version=1&modificationDate=1481813549000&api=v2)
#
# This figure is from [Tonry et al. (2012)](https://ui.adsabs.harvard.edu/abs/2012ApJ...750...99T/abstract).
#
# Each line in the figure corresponds to a filter used by Pan-STARRS.
# The filters we will use are the g (shown in light blue), r (shown in red), i (shown in yellow).
# The x-axis in the figure indicates the wavelengths (in nanometers) covered by the Pan-STARRS filters.
# The y-axis can be thought of how sensitive the telescope is to detecting light at each filter at that wavelength.
# As an example, you can see that the red filter covers wavelengths from around 550 to 700 nm.

# %% [markdown]
# ### Section 2.1: Downloading an image

# %% [markdown]
# Run the following cell to download three images taken by PanSTARRS taken in the g, r, and i filters.

# %%
# !wget -O crab_nebula_i.fits "https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63308333333332&dec=22.0145&size=1200&format=fits&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.i.unconv.fits"
# !wget -O crab_nebula_r.fits "https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63308333333332&dec=22.0145&size=1200&format=fits&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.r.unconv.fits"
# !wget -O crab_nebula_g.fits "https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63308333333332&dec=22.0145&size=1200&format=fits&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.g.unconv.fits"
# Out:
# --2025-06-11 04:05:29--  https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63308333333332&dec=22.0145&size=1200&format=fits&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.i.unconv.fits
# Resolving ps1images.stsci.edu (ps1images.stsci.edu)... 130.167.201.61
# Connecting to ps1images.stsci.edu (ps1images.stsci.edu)|130.167.201.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5780160 (5.5M) [image/x-fits]
# Saving to: ‘crab_nebula_i.fits’
#
# crab_nebula_i.fits  100%[===================>]   5.51M  22.7MB/s    in 0.2s
#
# 2025-06-11 04:05:30 (22.7 MB/s) - ‘crab_nebula_i.fits’ saved [5780160/5780160]
#
# --2025-06-11 04:05:30--  https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63308333333332&dec=22.0145&size=1200&format=fits&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.r.unconv.fits
# Resolving ps1images.stsci.edu (ps1images.stsci.edu)... 130.167.201.61
# Connecting to ps1images.stsci.edu (ps1images.stsci.edu)|130.167.201.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5777280 (5.5M) [image/x-fits]
# Saving to: ‘crab_nebula_r.fits’
#
# crab_nebula_r.fits  100%[===================>]   5.51M  25.0MB/s    in 0.2s
#
# 2025-06-11 04:05:31 (25.0 MB/s) - ‘crab_nebula_r.fits’ saved [5777280/5777280]
#
# --2025-06-11 04:05:31--  https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63308333333332&dec=22.0145&size=1200&format=fits&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.g.unconv.fits
# Resolving ps1images.stsci.edu (ps1images.stsci.edu)... 130.167.201.61
# Connecting to ps1images.stsci.edu (ps1images.stsci.edu)|130.167.201.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5777280 (5.5M) [image/x-fits]
# Saving to: ‘crab_nebula_g.fits’
#
# crab_nebula_g.fits  100%[===================>]   5.51M  22.7MB/s    in 0.2s
#
# 2025-06-11 04:05:32 (22.7 MB/s) - ‘crab_nebula_g.fits’ saved [5777280/5777280]

# %% [markdown]
# Run the next cell to see a list of the files in your directory. You should now see crab_nebula_i.fits, crab_nebula_r.fits, and crab_nebula_g.fits corresponding to the three different filters we will use (i, r, and g).

# %%
# !ls
# Out:
# crab_nebula_g.fits  crab_nebula_i.fits	crab_nebula_r.fits  sample_data

# %% [markdown]
# ### Section 2.2: Create your first image

# %% [markdown]
# Create an image using one of the three optical files you have downloaded.
#
# You may find it useful to reference the [astropy imaging notebook](https://github.com/psheehan/CIERA-HS-Program/blob/master/AstropyModule/Astropy-images.ipynb).
#
# It is also recommended to use `norm=LogNorm()` when you use `imshow()` as is demonstrated in the [astropy imaging notebook](https://github.com/psheehan/CIERA-HS-Program/blob/master/AstropyModule/Astropy-images.ipynb).

# %%
#
# Some code to help get you started
#
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from astropy.io import fits
from matplotlib.colors import LogNorm
from matplotlib.colors import *

hdul = fits.open("crab_nebula_r.fits")
data = hdul[0].data.squeeze()
hdr = hdul[0].header
hdul.close()

print(hdr)

plt.figure(figsize=(8, 8))
plt.imshow(data, origin='lower', cmap='inferno', norm=LogNorm())
plt.colorbar(label="Pixel Value")
plt.title(f"{hdr.get('OBJECT', 'Optical Image')}")
plt.xlabel("Pixel X")
plt.ylabel("Pixel Y")
plt.show()
# Out:
# SIMPLE  =                    T / file does conform to FITS standard             BITPIX  =                  -32 / number of bits per data pixel                  NAXIS   =                    2 / number of data axes                            NAXIS1  =                 1200 / length of data axis 1                          NAXIS2  =                 1200 / length of data axis 2                          EXTEND  =                    T / FITS dataset may contain extensions            COMMENT   FITS (Flexible Image Transport System) format is defined in 'AstronomyCOMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H DATE    = '2025-06-11T04:05:31' / file creation date (YYYY-MM-DDThh:mm:ss UT)   CTYPE1  = 'RA---TAN'                                                            CTYPE2  = 'DEC--TAN'                                                            CRVAL1  =     85.7142791747971                                                  CRVAL2  =     21.9999999999992                                                  CRPIX1  =              -27193. / Reference pixel shifted for cutout             CRPIX2  =                 203. / Reference pixel shifted for cutout             CDELT1  = 6.94444461259988E-05                                                  CDELT2  = 6.94444461259988E-05                                                  PC001001=                  -1.                                                  PC001002=                   0.                                                  PC002001=                   0.                                                  PC002002=                   1.                                                  HISTORY ppStack at 2015-02-05T05:48:26.683543                                   PSLIB_V = '37083   '                                                            HISTORY psLib version: tags/ipp-pv3-20140717/psLib@37083                        HISTORY psLib source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd                      MODULE_V= '37323:37768'                                                         HISTORY psModules version: tags/ipp-pv3-20140717/psModules@37323:37768          HISTORY psModules source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd                  PHOT_V  = '37083   '                                                            HISTORY psphot version: tags/ipp-pv3-20140717/psphot@37083                      HISTORY psphot source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd                     STATS_V = '37083   '                                                            HISTORY ppStats version: tags/ipp-pv3-20140717/ppStats@37083                    HISTORY ppStats source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd                    STACK_V = '37083   '                                                            HISTORY ppStack version: tags/ipp-pv3-20140717/ppStack@37083                    HISTORY ppStack source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd                    NINPUTS =                   16 / Number of input images                         STK_TYPE= 'DEEP_STACK'         / type of stack                                  STK_ID  = '4362088 '           / type of stack                                  SKYCELL = 'skycell.1784.059'   / type of stack                                  TESS_ID = 'RINGS.V3'           / type of stack                                  AIRM_SLP=                   0. / airmass slope                                  INP_0000= 'o6238g0569o.546240.wrp.1429532.skycell.1784.059.fits' / input image nINP_0001= 'o5814g0499o.390460.wrp.1429533.skycell.1784.059.fits' / input image nINP_0002= 'o5891g0283o.423884.wrp.1429535.skycell.1784.059.fits' / input image nINP_0003= 'o5891g0305o.423906.wrp.1429536.skycell.1784.059.fits' / input image nINP_0004= 'o6238g0587o.546260.wrp.1429537.skycell.1784.059.fits' / input image nINP_0005= 'o5192g0161o.114785.wrp.1429540.skycell.1784.059.fits' / input image nINP_0006= 'o6735g0156o.717525.wrp.1429541.skycell.1784.059.fits' / input image n ...

# %% [markdown]
# Do you notice anything weird about the areas outside of the Crab Nebula in your images?

# %%
#it seems like there is no data outside in those areas as it is white even though i am not using a gray colormap.

# %% [markdown]
# Use the figure at the beginning of Section 2. For the image you chose answer the following questions:
# * What is the average wavelength sampled by the filter? Use the green line for the g filter, the red line for the r filter, and yellow for the i filter.
# * What is the frequency of light at this wavelength in $m/s$?
# * What is the energy of light observed at this wavelength in Joules?

# %% [markdown]
# ### Section 2.3: Troubleshooting your image

# %% [markdown]
# An optical image can be thought of as a grid made up of individual pixels that record the amount of light reaching it. The data recorded from the pixels is combined to form the fits image you are plotting.
#
# There may be pixels without recorded values. These would show up as `null` values in your table. The numpy function `isnan()` may be useful to answer the following questions.
# * How many pixels have `null` values?
# * Create a version of your table without the null values.

# %%
import numpy as np
from astropy.io import fits

hdul = fits.open("crab_nebula_r.fits")
data = hdul[0].data.squeeze()
hdul.close()

num_null_pixels = np.isnan(data).sum()
print(f"Number of null (NaN) pixels: {num_null_pixels}")

data_clean = np.nan_to_num(data, nan=0.0)
# Out:
# Number of null (NaN) pixels: 7

# %% [markdown]
# Unfortunately, plotting your new table likely won't change the image because the pixels still have nothing there. But we are now in a much better place to start these next steps:
#
# * To start to understand what is happening to the areas outside of the Crab Nebula, create a histogram of the pixel values.

# %%
plt.hist(data_clean.flatten(), bins=100)
plt.xlabel("Pixel Value")
plt.ylabel("Number of Pixels")
plt.title("Histogram of Pixel Values")
plt.show()

# %% [markdown]
# What are the lowest and highest values recorded in your image?
#
# <font color='blue'>Hint: You can use numpy `min()` and `max()` functions to help find these values.</font>

# %%
print(f"Minimum pixel value: {np.min(data_clean)}")
print(f"Maximum pixel value: {np.max(data_clean)}")
# Out:
# Minimum pixel value: -1430.2520751953125
# Maximum pixel value: 618155.8125

# %% [markdown]
# In Section 2.2 we suggested using `norm=LogNorm()` when using `imshow`.
# With the default linear scaling, something twice as bright will be twice as bright in your image. However, when using `norm=LogNorm()`, matplotlib converts the normal (linear) scaling to a logarithmic one. Thus objects generally need to be 10 times as bright to be significantly brighter in your image. This helps us see both the really bright and really faint regions of the sky you are looking at.
# * What happens when you take the logarithm of your minimum and maximum cell values that you found in the previous step? The numpy `log10()` function may be useful here.

# %%
log_min = np.log10(np.min(data_clean))
log_max = np.log10(np.max(data_clean))

print(f"Minimum pixel value: {np.min(data_clean)}")
print(f"Maximum pixel value: {np.max(data_clean)}")
print(f"log10(min): {log_min}")
print(f"log10(max): {log_max}")
# Out:
# Minimum pixel value: -1430.2520751953125
# Maximum pixel value: 618155.8125
# log10(min): nan
# log10(max): 5.791098117828369
# <ipython-input-14-2158728671>:1: RuntimeWarning: invalid value encountered in log10
#   log_min = np.log10(np.min(data_clean))

# %% [markdown]
# You now know which values are causing the problem with our chosen scaling.
# * Create a new table that adds or subtracts to the image by an amount so that the scaling does not cause problems.
#
# * Plot this new image.
#
# * How does it look now?
#
# * What is the minimum value you need to adjust your image by for it to look better?

# %%
min_val = np.min(data_clean)
print(f"Original min pixel value: {min_val}")

epsilon = 1e-3  # small buffer
shift_value = abs(min_val) + epsilon
data_shifted = data_clean + shift_value

plt.figure(figsize=(8, 8))
plt.imshow(data_shifted, origin='lower', cmap='cividis', norm=LogNorm())
plt.colorbar(label="Shifted Intensity [arbitrary units]")
plt.title("Shifted Image with LogNorm Scaling")
plt.xlabel("Pixel X")
plt.ylabel("Pixel Y")
plt.show()
# Out:
# Original min pixel value: -1430.2520751953125

# %% [markdown]
# ### Section 2.4: Create images from all three filters

# %% [markdown]
# Now that you've successfully created an image for one filter.
#
# * Create images for **each** of the three filters you downloaded earlier.
#
# <font color='blue'>Hint: It might save work for you to place your plotting code from the previous sections into a function and/or loop to save you time and create consistency.</font>

# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import os

fits_files = ["crab_nebula_g.fits", "crab_nebula_i.fits", "crab_nebula_r.fits"]

def plot_fits_log_scaled(filename, cmap='plasma', epsilon=1e-3):
    hdul = fits.open(filename)
    data = hdul[0].data.squeeze()
    hdr = hdul[0].header
    hdul.close()

    data_clean = np.nan_to_num(data, nan=0.0)

    min_val = np.min(data_clean)
    shift = abs(min_val) + epsilon
    data_shifted = data_clean + shift

    plt.figure(figsize=(8, 8))
    plt.imshow(data_shifted, origin='lower', cmap=cmap, norm=LogNorm())
    plt.colorbar(label="Shifted Intensity [a.u.]")
    plt.title(f"{hdr.get('OBJECT', os.path.basename(filename))} ({filename})")
    plt.xlabel("Pixel X")
    plt.ylabel("Pixel Y")
    plt.tight_layout()

for file in fits_files:
    plot_fits_log_scaled(file)

# %% [markdown]
# For *all three images*:
#
# * What is the frequency of light at this wavelength in $m/s$?
# * What is the energy of the photons observed at this wavelength in Joules?
#
# <font color='blue'>Hint: You should have already calculated this for one of the images you created.</font>

# %%
from astropy.io import fits

c = 2.99792458e8
h = 6.62607015e-34

for file in fits_files:
    hdr = fits.getheader(file)
    wavelength = hdr.get("WAVELEN", None) or hdr.get("FILTER", None)

    if wavelength is None:
        wavelength = hdr.get("CRVAL1", None)
    if wavelength is None:
        print(f"{file}: Wavelength not found in header.")
        continue

    if wavelength > 1e-6:
        wavelength_m = wavelength * 1e-9  # assuming nm
    else:
        wavelength_m = wavelength

    frequency = c / wavelength_m
    energy = h * frequency

    print(f"\nFile: {file}")
    print(f"  Wavelength: {wavelength_m:.2e} m")
    print(f"  Frequency: {frequency:.2e} Hz")
    print(f"  Photon energy: {energy:.2e} J")
# Out:
# File: crab_nebula_g.fits
#   Wavelength: 8.57e-08 m
#   Frequency: 3.50e+15 Hz
#   Photon energy: 2.32e-18 J
#
# File: crab_nebula_i.fits
#   Wavelength: 8.57e-08 m
#   Frequency: 3.50e+15 Hz
#   Photon energy: 2.32e-18 J
#
# File: crab_nebula_r.fits
#   Wavelength: 8.57e-08 m
#   Frequency: 3.50e+15 Hz
#   Photon energy: 2.32e-18 J

# %% [markdown]
# Some questions to reflect on:
# *   Are there parts *within* the Crab Nebula that you see better in one image than the others?
# *   Are there regions *outside* of the Crab Nebula that appear better in one filter than the others?
# *   Do you have an image that you think looks best overall?

# %%
'''
1. Are there parts within the Crab Nebula that you see better in one image than the others?
Yes — different filters isolate different emission lines or physical processes:

Red filter (e.g., H-alpha or [S II]): may highlight ionized hydrogen and shock-excited filaments —long, thread-like structures seen more clearly here.

Green/Visible continuum filter: often shows a blend of gas and starlight — you may see central pulsar light and finer textures.

Blue filter (e.g., [O III]): tends to emphasize high-energy, hotter gas regions, often showing expanding shells or arcs.


2. Are there regions outside of the Crab Nebula that appear better in one filter than the others?
  Yes — filters sensitive to shorter wavelengths (blue) may:


3. Do you have an image that you think looks best overall?
The composite RGB image combining all three filters looks the best in my opinion
It balances the brightness extremes using log/Asinh stretch.

You get spatial structure and spectral diversity in one glance.

It most closely resembles the way composite color Hubble images are created.

If you had to pick one monochrome filter, it depends on your science goal:

Studying dynamics and expansion? Blue ([O III]) may be best.

Looking at structure and fine filaments? Red (H-alpha/[S II]) often wins.
'''
# Out:
# '\n1. Are there parts within the Crab Nebula that you see better in one image than the others?\nYes — different filters isolate different emission lines or physical processes:\n\nRed filter (e.g., H-alpha or [S II]): may highlight ionized hydrogen and shock-excited filaments —long, thread-like structures seen more clearly here.\n\nGreen/Visible continuum filter: often shows a blend of gas and starlight — you may see central pulsar light and finer textures.\n\nBlue filter (e.g., [O III]): tends to emphasize high-energy, hotter gas regions, often showing expanding shells or arcs.\n\n\n2. Are there regions outside of the Crab Nebula that appear better in one filter than the others?\n  Yes — filters sensitive to shorter wavelengths (blue) may:\n\n\n3. Do you have an image that you think looks best overall?\nThe composite RGB image combining all three filters looks the best in my opinion\nIt balances the brightness extremes using log/Asinh stretch.\n\nYou get spatial structure and spectral diversity in one glance.\n\nIt most closely resembles the way composite color Hubble images are created.\n\nIf you had to pick one monochrome filter, it depends on your science goal:\n\nStudying dynamics and expansion? Blue ([O III]) may be best.\n\nLooking at structure and fine filaments? Red (H-alpha/[S II]) often wins.\n'

# %% [markdown]
# ## Section 3: Radio observations - a frequency view of the electromagnetic spectrum

# %% [markdown]
# In this section we will use an image of the Crab Nebula from the VLA. In particular, this image is from the NRAO VLA Sky Survey, which is typically shortened to [NVSS](https://www.cv.nrao.edu/nvss/). You can download an image by running the following cell.

# %%
# !wget https://github.com/CIERA-Northwestern/REACHpy/raw/main/Projects/MultiwavelengthImaging/images/crab_nvss.fits
# Out:
# --2025-06-11 04:34:46--  https://github.com/CIERA-Northwestern/REACHpy/raw/main/Projects/MultiwavelengthImaging/images/crab_nvss.fits
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/CIERA-Northwestern/REACHpy/main/Projects/MultiwavelengthImaging/images/crab_nvss.fits [following]
# --2025-06-11 04:34:47--  https://raw.githubusercontent.com/CIERA-Northwestern/REACHpy/main/Projects/MultiwavelengthImaging/images/crab_nvss.fits
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 826560 (807K) [application/octet-stream]
# Saving to: ‘crab_nvss.fits’
#
# crab_nvss.fits      100%[===================>] 807.19K  --.-KB/s    in 0.06s
#
# 2025-06-11 04:34:47 (14.1 MB/s) - ‘crab_nvss.fits’ saved [826560/826560]

# %% [markdown]
# Create an image of this file and compare it to the optical images.

# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import requests

nvss_url = "https://github.com/CIERA-Northwestern/REACHpy/raw/main/Projects/MultiwavelengthImaging/images/crab_nvss.fits"  # example URL
nvss_filename = "nvss_crab.fits"
response = requests.get(nvss_url)
with open(nvss_filename, "wb") as f:
    f.write(response.content)

hdul = fits.open(nvss_filename)
data = hdul[0].data.squeeze()
hdr = hdul[0].header
hdul.close()

data = np.nan_to_num(data, nan=0.0)

min_val = np.min(data)
shift = abs(min_val) + 1e-3
data_shifted = data + shift

plt.figure(figsize=(8, 8))
plt.imshow(data_shifted, origin="lower", cmap="inferno", norm=LogNorm())
plt.colorbar(label="Radio Intensity [a.u.]")
plt.title("Crab Nebula – VLA NVSS (Radio)")
plt.xlabel("Pixel X")
plt.ylabel("Pixel Y")
plt.show()

# %% [markdown]
# How does this image compare to the optical images?

# %%
'''The NVSS radio image of the Crab Nebula looks pretty different from the optical ones. It’s a lot smoother and more spread out, without the sharp filaments and fine details you see in the optical images. While the optical views show all the wispy structures and even the central pulsar, the radio image mainly captures the bigger picture—like the glow from energetic particles and magnetic fields. It doesn't have as much detail, but it gives you a sense of the overall shape and energy of the nebula. Both views are cool in their own way and show different sides of what's going on.'''
# Out:
# "The NVSS radio image of the Crab Nebula looks pretty different from the optical ones. It’s a lot smoother and more spread out, without the sharp filaments and fine details you see in the optical images. While the optical views show all the wispy structures and even the central pulsar, the radio image mainly captures the bigger picture—like the glow from energetic particles and magnetic fields. It doesn't have as much detail, but it gives you a sense of the overall shape and energy of the nebula. Both views are cool in their own way and show different sides of what's going on."

# %% [markdown]
# We can measure the size of the pixels in arcseconds. One arcsecond is equal to 1/3600 of a degree.
#
# The NVSS image originally had pixels that are approximately 15 arcseconds across. The optical images had pixels that were approximately 0.26 arcseconds across. Does this help explain the difference between the optical and radio images?

# %%
'''Yes, the difference in pixel size helps explain a lot. The NVSS radio image has pixels about 15 arcseconds wide, while the optical images have pixels only 0.26 arcseconds wide — that means the optical images have much higher resolution. So while the radio image shows the general shape and large-scale structure, it can’t capture the fine details and sharp filaments that the optical images do. It's like comparing a blurry zoomed-out view to a crisp close-up — both are useful, but they reveal different levels of detail.'''
# Out:
# "Yes, the difference in pixel size helps explain a lot. The NVSS radio image has pixels about 15 arcseconds wide, while the optical images have pixels only 0.26 arcseconds wide — that means the optical images have much higher resolution. So while the radio image shows the general shape and large-scale structure, it can’t capture the fine details and sharp filaments that the optical images do. It's like comparing a blurry zoomed-out view to a crisp close-up — both are useful, but they reveal different levels of detail."

# %% [markdown]
# This radio image was taken at a frequency of 1 GHz or $10^{9}\,\textrm{Hz}.$
#
# * What is the energy of the photons observed at this frequency in Joules?
# * What is the wavelength of light at this frequency in meters?
# * How much larger is the wavelength of the radio observations than the optical images you created in the previous section?

# %% [markdown]
# ## Section 4: X-ray observations - an energy view of the electromagnetic spectrum

# %% [markdown]
# We will download an image taken by the [Chandra X-ray Observatory](https://chandra.harvard.edu/).
#
# Run the following cell to download a file named `chandra_b_bandpass.fits` that you will use in the following steps.

# %%
# !wget -O chandra_b_bandpass.fits 'https://cda.cfa.harvard.edu/csccli/retrieveFile?filename=acisf13210_000N020_b_img3.fits&filetype=ecorrimg&version=cur'
# Out:
# --2025-06-11 04:38:26--  https://cda.cfa.harvard.edu/csccli/retrieveFile?filename=acisf13210_000N020_b_img3.fits&filetype=ecorrimg&version=cur
# Resolving cda.cfa.harvard.edu (cda.cfa.harvard.edu)... 131.142.198.67
# Connecting to cda.cfa.harvard.edu (cda.cfa.harvard.edu)|131.142.198.67|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/fits]
# Saving to: ‘chandra_b_bandpass.fits’
#
# chandra_b_bandpass.     [ <=>                ] 707.97K  4.27MB/s    in 0.2s
#
# 2025-06-11 04:38:26 (4.27 MB/s) - ‘chandra_b_bandpass.fits’ saved [724961]

# %% [markdown]
# ### Section 4.1: Create an image

# %% [markdown]
# Create an image of the region in X-rays.

# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

filename = "chandra_b_bandpass.fits"
hdul = fits.open(filename)
data = hdul[0].data.squeeze()
hdr = hdul[0].header
hdul.close()

data = np.nan_to_num(data, nan=0.0)
data[data <= 0] = np.nan  # mask non-positive values
positive_data = data[np.isfinite(data) & (data > 0)]

if positive_data.size == 0:
    raise ValueError("No strictly positive pixel values available for LogNorm scaling.")

vmin = np.nanmin(positive_data)
vmax = np.nanmax(positive_data)

masked_data = np.ma.masked_invalid(data)

plt.figure(figsize=(8, 8))
plt.imshow(masked_data, origin='lower', cmap='inferno', norm=LogNorm(vmin=vmin, vmax=vmax))
plt.colorbar(label="X-ray Intensity [a.u.]")
plt.title("Chandra X-ray Image (Log Scale)")
plt.xlabel("Pixel X")
plt.ylabel("Pixel Y")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-2908263052> in <cell line: 0>()
#      24 plt.figure(figsize=(8, 8))
#      25 plt.imshow(masked_data, origin='lower', cmap='inferno', norm=LogNorm(vmin=vmin, vmax=vmax))
# ---> 26 plt.colorbar(label="X-ray Intensity [a.u.]")
#      27 plt.title("Chandra X-ray Image (Log Scale)")
#      28 plt.xlabel("Pixel X")
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kwargs)
#    2530                                'an image (with imshow) or a contour set ('
#    2531                                'with contourf).')
# -> 2532     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2533     return ret
#    2534
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1306         NON_COLORBAR_KEYS = [  # remove kws that cannot be passed to Colorbar
#    1307             'fraction', 'pad', 'shrink', 'aspect', 'anchor', 'panchor']
# -> 1308         cb = cbar.Colorbar(cax, mappable, **{
#    1309             k: v for k, v in kwargs.items() if k not in NON_COLORBAR_KEYS})
#    1310         cax.get_figure(root=False).stale = True
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, extendfrac, extendrect, label, location)
#     406         else:
#     407             self._formatter = format  # Assume it is a Formatter or None
# --> 408         self._draw_all()
#     409
#     410         if isinstance(mappable, contour.ContourSet) and not mappable.filled:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/colorbar.py in _draw_all(self)
#     548         self.vmin, self.vmax = self._boundaries[self._inside][[0, -1]]
#     549         # Compute the X/Y mesh.
# --> 550         X, Y = self._mesh()
#     551         # draw the extend triangles, and shrink the inner Axes to accommodate.
#     552         # also adds the outline path to self.outline spine:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/colorbar.py in _mesh(self)
#    1135             with (self.norm.callbacks.blocked(),
#    1136                   cbook._setattr_cm(self.norm, vmin=self.vmin, vmax=self.vmax)):
# -> 1137                 y = self.norm.inverse(y)
#    1138         self._y = y
#    1139         X, Y = np.meshgrid([0., 1.], y)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py in inverse(self, value)
#    2689             t_vmin, t_vmax = self._trf.transform([self.vmin, self.vmax])
#    2690             if not np.isfinite([t_vmin, t_vmax]).all():
# -> 2691                 raise ValueError("Invalid vmin or vmax")
#    2692             value, is_scalar = self.process_value(value)
#    2693             rescaled = value * (t_vmax - t_vmin)
#
# ValueError: Invalid vmin or vmax

# %% [markdown]
# Compare this image to the optical and radio images you created. Is it similar or does it look significantly different?

# %%
#It is significantly different. There is no color in this and there is a central object which was not there in the other images.

# %% [markdown]
# Are there any irregularities in this image (gaps, missing data, or anything else)? If so, describe these problems and how they are different than the issues we found with the optical images.

# %%
#The data around the square has no data which can be fixed by changing the plotting boundaries.

# %% [markdown]
# X-ray astronomers usually describe the part of the electromagnetic spectrum they are observing in terms of the energies they are observing in units of electron volts (eV). $1\,\textrm{eV} = 1.6022\times10^{−19}\,\textrm{J}$.
#
# This image contains observations at approximately 2.3 keV (or $2.3\times10^3\,$eV).
# By combining equations 1 and 2 from the introduction, and converting our equations from Joules (SI units) to electron volts (favored by X-ray astronomers), we have the following:
#
# $\lambda = \frac{h c}{E}$
#
# where
# * E is the energy,
# * h is Planck's constant ($4.1357\times10^{-15}\,\textrm{eV}\,\textrm{s}$), and
# * c is the speed of light ($2.9979\times10^{8}\,\textrm{m/s}$).

# %% [markdown]
# Aided with the equations 1, 2 and the equation above:
#
# * Calculate the wavelength and frequency of the X-ray light.

# %%
E_eV = 2.3e3
h_eVs = 4.1357e-15
c = 2.9979e8

wavelength_m = (h_eVs * c) / E_eV

frequency_Hz = E_eV / h_eVs

print(f"Wavelength: {wavelength_m:.3e} meters")
print(f"Frequency: {frequency_Hz:.3e} Hz")
# Out:
# Wavelength: 5.391e-10 meters
# Frequency: 5.561e+17 Hz

# %% [markdown]
# Final questions:
# * How much more energetic are the X-ray photons you are observing compared to the optical and radio photons?
# * How does the frequency compare to the optical and radio images?

# %%
h_eVs = 4.1357e-15
c = 2.9979e8

wavelengths = {
    "X-ray (2.3 keV)": (2.3e3, None),
    "Optical (~620 nm)": (None, 620e-9),
    "Radio (~21 cm)": (None, 0.21)
}

for band, (energy_eV, wavelength_m) in wavelengths.items():
    if energy_eV is None:
        frequency_Hz = c / wavelength_m
        energy_eV = h_eVs * frequency_Hz
    else:
        frequency_Hz = energy_eV / h_eVs
        wavelength_m = h_eVs * c / energy_eV

    print(f"\n{band}")
    print(f"  Wavelength: {wavelength_m:.3e} m")
    print(f"  Frequency:  {frequency_Hz:.3e} Hz")
    print(f"  Energy:     {energy_eV:.3e} eV")

E_xray = 2.3e3  # eV
E_optical = h_eVs * (c / 620e-9)
E_radio = h_eVs * (c / 0.21)

print("\nEnergy Ratios (compared to X-ray):")
print(f"  Optical:  1 X-ray photon = {E_xray / E_optical:.2e} optical photons")
print(f"  Radio:    1 X-ray photon = {E_xray / E_radio:.2e} radio photons")
# Out:
# X-ray (2.3 keV)
#   Wavelength: 5.391e-10 m
#   Frequency:  5.561e+17 Hz
#   Energy:     2.300e+03 eV
#
# Optical (~620 nm)
#   Wavelength: 6.200e-07 m
#   Frequency:  4.835e+14 Hz
#   Energy:     2.000e+00 eV
#
# Radio (~21 cm)
#   Wavelength: 2.100e-01 m
#   Frequency:  1.428e+09 Hz
#   Energy:     5.904e-06 eV
#
# Energy Ratios (compared to X-ray):
#   Optical:  1 X-ray photon = 1.15e+03 optical photons
#   Radio:    1 X-ray photon = 3.90e+08 radio photons

# %% [markdown]
# ## Section 6: More information

# %% [markdown]
# Here are some additional links:
#
# *   [Radio/infrared/optical/ultraviolet/X-ray Crab Nebula](https://public.nrao.edu/gallery/a-new-look-at-the-crab-nebula-individual-wavelength-thumbnails/)
# *   [Astronomy picture of the day](https://apod.nasa.gov/apod/astropix.html)
